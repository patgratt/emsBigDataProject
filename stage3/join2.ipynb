# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/patrickburke/Library/CloudStorage/OneDrive-EmoryUniversity/ECON496RW/raceANDcomp/v1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    PcrKey  black  white  hispanic_latino  asian  \
# 0           0  13273412      0      1                0      0
# 1           1  17184298      0      1                0      0
# 2           2  21699657      0      1                0      0
# 3           3  72057010      0      1                0      0
# 4           4  83733589      0      0                0      0
#
#    americanIndian_alaskaNative  nativeHawaiian_otherPacificIslander ageinyear  \
# 0                            0                                    0        78
# 1                            0                                    0        10
# 2                            0                                    0        84
# 3                            0                                    0        84
# 4                            1                                    0        31
#
#   EMSSystemResponseTimeMin
# 0             8.6333333333
# 1                        .
# 2                        .
# ...

# %% [markdown]
# - gosh darn I forgot to put index = false

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.head(50)
# Out:
#        PcrKey  black  white  hispanic_latino  asian  \
# 0    13273412      0      1                0      0
# 1    17184298      0      1                0      0
# 2    21699657      0      1                0      0
# 3    72057010      0      1                0      0
# 4    83733589      0      0                0      0
# 5    88178354      0      1                0      0
# 6    97455081      0      1                0      0
# 7   102488422      0      1                0      0
# 8   107295362      0      1                0      0
# 9   110454483      0      0                0      0
# 10  116400273      0      1                0      0
# 11  118170828      0      1                0      0
# 12  118170830      0      1                0      0
# 13  118170835      0      1                0      0
# 14  118170838      1      0                0      0
# 15  118170842      1      0                0      0
# 16  118170844      0      1                0      0
# ...

# %% [markdown]
# - LAST THING before I can build a model is to drop rows with missing data for age and for EMSSystemResponseTimeMin

# %%
# this grabs by [y, x]
print(df.iloc[1,8])
print(type(df.iloc[1,8]))
# Out:
# .
# <class 'str'>

# %% [markdown]
# - yea so those periods that essentially represent missing data are strings which is pretty annoying as that's creating a ton of bloat

# %%
print(df.iloc[0,8])
print(type(df.iloc[1,8]))
# Out:
# 8.6333333333
# <class 'str'>

# %% [markdown]
# - wow even the numbers are strings what the heck

# %%
df.dtypes
# Out:
# PcrKey                                  int64
# black                                   int64
# white                                   int64
# hispanic_latino                         int64
# asian                                   int64
# americanIndian_alaskaNative             int64
# nativeHawaiian_otherPacificIslander     int64
# ageinyear                              object
# EMSSystemResponseTimeMin               object
# dtype: object

# %% [markdown]
# - yea so we need to fix that
# - at least all the missing data is periods so we can pretty easily just drop all of those

# %%
# this will get rid of all the dots in the age column
df = df[(df['ageinyear'] != ".")]

# %%
df.head(50)
# Out:
#        PcrKey  black  white  hispanic_latino  asian  \
# 0    13273412      0      1                0      0
# 1    17184298      0      1                0      0
# 2    21699657      0      1                0      0
# 3    72057010      0      1                0      0
# 4    83733589      0      0                0      0
# 5    88178354      0      1                0      0
# 6    97455081      0      1                0      0
# 7   102488422      0      1                0      0
# 8   107295362      0      1                0      0
# 9   110454483      0      0                0      0
# 10  116400273      0      1                0      0
# 11  118170828      0      1                0      0
# 12  118170830      0      1                0      0
# 13  118170835      0      1                0      0
# 14  118170838      1      0                0      0
# 15  118170842      1      0                0      0
# 16  118170844      0      1                0      0
# ...

# %%
len(df.index)
# Out:
# 32582122

# %%
df = df[(df['EMSSystemResponseTimeMin'] != ".")]

# %%
df.head(50)
# Out:
#        PcrKey  black  white  hispanic_latino  asian  \
# 0    13273412      0      1                0      0
# 4    83733589      0      0                0      0
# 5    88178354      0      1                0      0
# 6    97455081      0      1                0      0
# 7   102488422      0      1                0      0
# 8   107295362      0      1                0      0
# 9   110454483      0      0                0      0
# 10  116400273      0      1                0      0
# 11  118170828      0      1                0      0
# 12  118170830      0      1                0      0
# 13  118170835      0      1                0      0
# 14  118170838      1      0                0      0
# 15  118170842      1      0                0      0
# 16  118170844      0      1                0      0
# 17  118170847      0      1                0      0
# 18  118170848      0      1                0      0
# 19  118170851      0      0                1      0
# ...

# %% [markdown]
# - Boom perfect

# %%
df.dtypes
# Out:
# PcrKey                                  int64
# black                                   int64
# white                                   int64
# hispanic_latino                         int64
# asian                                   int64
# americanIndian_alaskaNative             int64
# nativeHawaiian_otherPacificIslander     int64
# ageinyear                              object
# EMSSystemResponseTimeMin               object
# dtype: object

# %%
# fix types
# I'm gonna keep the booleans as ints for now
df.astype({
'PcrKey'                              :'int32',
'white'                               :'int32',
'hispanic_latino'                     :'int32',
'asian'                               :'int32',
'black'                               :'int32',
'americanIndian_alaskaNative'         :'int32',
'nativeHawaiian_otherPacificIslander' :'int32',
'ageinyear'                           :'int32',
'EMSSystemResponseTimeMin'            :'float32'
}).dtypes
# Out:
# PcrKey                                   int32
# black                                    int32
# white                                    int32
# hispanic_latino                          int32
# asian                                    int32
# americanIndian_alaskaNative              int32
# nativeHawaiian_otherPacificIslander      int32
# ageinyear                                int32
# EMSSystemResponseTimeMin               float32
# dtype: object

# %%
df.head()
# Out:
#       PcrKey  black  white  hispanic_latino  asian  \
# 0   13273412      0      1                0      0
# 4   83733589      0      0                0      0
# 5   88178354      0      1                0      0
# 6   97455081      0      1                0      0
# 7  102488422      0      1                0      0
#
#    americanIndian_alaskaNative  nativeHawaiian_otherPacificIslander ageinyear  \
# 0                            0                                    0        78
# 4                            1                                    0        31
# 5                            0                                    0        85
# 6                            0                                    0        77
# 7                            0                                    0         4
#
#   EMSSystemResponseTimeMin
# 0             8.6333333333
# 4                     29.0
# 5                      3.0
# 6                    109.0
# 7                     31.0

# %%
df.reset_index(drop=True)
# Out:
#              PcrKey  black  white  hispanic_latino  asian  \
# 0          13273412      0      1                0      0
# 1          83733589      0      0                0      0
# 2          88178354      0      1                0      0
# 3          97455081      0      1                0      0
# 4         102488422      0      1                0      0
# ...             ...    ...    ...              ...    ...
# 32417152  182540290      1      0                0      0
# 32417153  182540377      1      0                0      0
# 32417154  182540383      1      0                0      0
# 32417155  182541657      0      1                0      0
# 32417156  182544491      0      1                0      0
#
#           americanIndian_alaskaNative  nativeHawaiian_otherPacificIslander  \
# 0                                   0                                    0
# 1                                   1                                    0
# ...

# %%
df.to_csv('/Users/patrickburke/Library/CloudStorage/OneDrive-EmoryUniversity/ECON496RW/raceANDcomp/v2.csv',index=False)
