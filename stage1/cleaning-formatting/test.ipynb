# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/patrickburke/Library/CloudStorage/OneDrive-EmoryUniversity/ECON496RW/cleaned_big/computedelements_chunks/computedelements_chunk1.csv")

# %%
df.head(50)
# Out:
#        PcrKey USCensusRegion    USCensusDivision   NasemsoRegion  Urbanicity  \
# 0     1472192      Northeast         New England            East         NaN
# 1    13273412           West            Mountain            West       Urban
# 2    14548133           West            Mountain  Western Plains       Rural
# 3    17184298        Midwest  West North Central     Great Lakes       Urban
# 4    21699657        Midwest  West North Central  Western Plains    Suburban
# 5    21719864      Northeast         New England            East         NaN
# 6    72057010        Midwest  West North Central  Western Plains    Suburban
# 7    73335292      Northeast     Middle Atlantic            East       Urban
# 8    79846935        Midwest  West North Central  Western Plains         NaN
# 9    81481800      Northeast     Middle Atlantic            East       Urban
# 10   81954292      Northeast     Middle Atlantic            East       Urban
# ...

# %%
df2 = pd.read_csv("/Users/patrickburke/Library/CloudStorage/OneDrive-EmoryUniversity/ECON496RW/cleaned_big/computedelements_chunks/computedelements_chunk2.csv")

# %%
df.head(50)
# Out:
#        PcrKey USCensusRegion    USCensusDivision   NasemsoRegion  Urbanicity  \
# 0     1472192      Northeast         New England            East         NaN
# 1    13273412           West            Mountain            West       Urban
# 2    14548133           West            Mountain  Western Plains       Rural
# 3    17184298        Midwest  West North Central     Great Lakes       Urban
# 4    21699657        Midwest  West North Central  Western Plains    Suburban
# 5    21719864      Northeast         New England            East         NaN
# 6    72057010        Midwest  West North Central  Western Plains    Suburban
# 7    73335292      Northeast     Middle Atlantic            East       Urban
# 8    79846935        Midwest  West North Central  Western Plains         NaN
# 9    81481800      Northeast     Middle Atlantic            East       Urban
# 10   81954292      Northeast     Middle Atlantic            East       Urban
# ...
