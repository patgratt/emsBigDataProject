# %%
import os
import pandas as pd
import numpy as np

# %%
# macbook
# folder = '/Users/patrickburke/Library/CloudStorage/OneDrive-EmoryUniversity/ECON496RW/processedCSVs/big/pub_pcrevents_chunks/'

# pc
folder = r'C:\Users\gratt\Desktop\emsData\processedCSVs\big\pub_pcrevents_chunks'

# %%
filepaths = [os.path.join(folder, filename) for filename in os.listdir(folder)]
filepaths
# Out:
# ['C:\\Users\\gratt\\Desktop\\emsData\\processedCSVs\\big\\pub_pcrevents_chunks\\pub_pcrevents_chunk1.csv',
#  'C:\\Users\\gratt\\Desktop\\emsData\\processedCSVs\\big\\pub_pcrevents_chunks\\pub_pcrevents_chunk10.csv',
#  'C:\\Users\\gratt\\Desktop\\emsData\\processedCSVs\\big\\pub_pcrevents_chunks\\pub_pcrevents_chunk2.csv',
#  'C:\\Users\\gratt\\Desktop\\emsData\\processedCSVs\\big\\pub_pcrevents_chunks\\pub_pcrevents_chunk3.csv',
#  'C:\\Users\\gratt\\Desktop\\emsData\\processedCSVs\\big\\pub_pcrevents_chunks\\pub_pcrevents_chunk4.csv',
#  'C:\\Users\\gratt\\Desktop\\emsData\\processedCSVs\\big\\pub_pcrevents_chunks\\pub_pcrevents_chunk5.csv',
#  'C:\\Users\\gratt\\Desktop\\emsData\\processedCSVs\\big\\pub_pcrevents_chunks\\pub_pcrevents_chunk6.csv',
#  'C:\\Users\\gratt\\Desktop\\emsData\\processedCSVs\\big\\pub_pcrevents_chunks\\pub_pcrevents_chunk7.csv',
#  'C:\\Users\\gratt\\Desktop\\emsData\\processedCSVs\\big\\pub_pcrevents_chunks\\pub_pcrevents_chunk8.csv',
#  'C:\\Users\\gratt\\Desktop\\emsData\\processedCSVs\\big\\pub_pcrevents_chunks\\pub_pcrevents_chunk9.csv']

# %%
def importGender(filepath):
    return pd.read_csv(filepath, usecols=["PcrKey", "ePatient_13"], dtype=np.int32)

# %%
df = pd.concat(map(importGender, filepaths))

# %%
df
# Out:
#             PcrKey  ePatient_13
# 0          1472192      7701003
# 1         13273412      9906003
# 2         14548133      9906001
# 3         17184298      9906003
# 4         21699657      9906003
# ...            ...          ...
# 4999995  168637681      7701001
# 4999996  168637682      9906003
# 4999997  168637683      9906003
# 4999998  168637684      9906001
# 4999999  168637685      9906001
#
# [48982990 rows x 2 columns]

# %%
df = df.rename(columns= {'ePatient_13' : 'Gender'})
# female = 9906001, change to 1
df = df.replace([9906001], 1)
# male = 9906003, change to 0
df = df.replace([9906003], 0)

# %%
df.head()
# Out:
#      PcrKey   Gender
# 0   1472192  7701003
# 1  13273412        0
# 2  14548133        1
# 3  17184298        0
# 4  21699657        0

# %%
# drop missing data rows
df = df[ (df['Gender'] == 0) | (df['Gender'] == 1) ]

# %%
df
# Out:
#             PcrKey  Gender
# 1         13273412       0
# 2         14548133       1
# 3         17184298       0
# 4         21699657       0
# 5         21719864       1
# ...            ...     ...
# 4999994  168637680       1
# 4999996  168637682       0
# 4999997  168637683       0
# 4999998  168637684       1
# 4999999  168637685       1
#
# [41748496 rows x 2 columns]

# %%
socioeconomic = pd.read_csv(r"C:\Users\gratt\Desktop\emsData\readyForStats\full\racesplus2.csv")

# %%
socioeconomic
# Out:
#              PcrKey  black  white  hispanic_latino  asian  \
# 0          13273412      0      1                0      0
# 1          83733589      0      0                0      0
# 2          88178354      0      1                0      0
# 3          97455081      0      1                0      0
# 4         102488422      0      1                0      0
# ...             ...    ...    ...              ...    ...
# 32417152  182540290      1      0                0      0
# 32417153  182540377      1      0                0      0
# 32417154  182540383      1      0                0      0
# 32417155  182541657      0      1                0      0
# 32417156  182544491      0      1                0      0
#
#           americanIndian_alaskaNative  nativeHawaiian_otherPacificIslander  \
# 0                                   0                                    0
# 1                                   1                                    0
# 2                                   0                                    0
# 3                                   0                                    0
# 4                                   0                                    0
# ...                               ...                                  ...
# 32417152                            0                                    0
# 32417153                            0                                    0
# 32417154                            0                                    0
# 32417155                            0                                    0
# 32417156                            0                                    0
#
#           ageinyear  EMSSystemResponseTimeMin
# 0                78                  8.633333
# 1                31                 29.000000
# 2                85                  3.000000
# 3                77                109.000000
# 4                 4                 31.000000
# ...             ...                       ...
# 32417152         77                 11.250000
# 32417153         54                  9.000000
# 32417154         78                 40.100000
# 32417155         74                  3.000000
# 32417156         75                  9.900000
#
# [32417157 rows x 9 columns]

# %%
socioeconomic = socioeconomic.drop(columns="EMSSystemResponseTimeMin")

# %%
socioeconomic
# Out:
#            black  white  hispanic_latino  asian  americanIndian_alaskaNative  \
# PcrKey
# 13273412       0      1                0      0                            0
# 83733589       0      0                0      0                            1
# 88178354       0      1                0      0                            0
# 97455081       0      1                0      0                            0
# 102488422      0      1                0      0                            0
# ...          ...    ...              ...    ...                          ...
# 182540290      1      0                0      0                            0
# 182540377      1      0                0      0                            0
# 182540383      1      0                0      0                            0
# 182541657      0      1                0      0                            0
# 182544491      0      1                0      0                            0
#
#            nativeHawaiian_otherPacificIslander  ageinyear
# PcrKey
# 13273412                                     0         78
# 83733589                                     0         31
# 88178354                                     0         85
# 97455081                                     0         77
# 102488422                                    0          4
# ...                                        ...        ...
# 182540290                                    0         77
# 182540377                                    0         54
# 182540383                                    0         78
# 182541657                                    0         74
# 182544491                                    0         75
#
# [32417157 rows x 7 columns]

# %%
df
# Out:
#            Gender
# PcrKey
# 13273412        0
# 14548133        1
# 17184298        0
# 21699657        0
# 21719864        1
# ...           ...
# 168637680       1
# 168637682       0
# 168637683       0
# 168637684       1
# 168637685       1
#
# [41748496 rows x 1 columns]

# %%
df = df.set_index('PcrKey')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\gratt\repos\emsBigDataProject\stage2-dataWrangling\sex.ipynb Cell 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gratt/repos/emsBigDataProject/stage2-dataWrangling/sex.ipynb#X62sZmlsZQ%3D%3D?line=0'>1</a> df = df.set_index('PcrKey')
#
# File c:\Users\gratt\miniconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\gratt\miniconda3\lib\site-packages\pandas\core\frame.py:6001, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5998                 missing.append(col)
#    6000 if missing:
# -> 6001     raise KeyError(f"None of {missing} are in the columns")
#    6003 if inplace:
#    6004     frame = self
#
# KeyError: "None of ['PcrKey'] are in the columns"

# %%
df = df.astype(int)
df
# Out:
#            Gender
# PcrKey
# 13273412        0
# 14548133        1
# 17184298        0
# 21699657        0
# 21719864        1
# ...           ...
# 168637680       1
# 168637682       0
# 168637683       0
# 168637684       1
# 168637685       1
#
# [41748496 rows x 1 columns]

# %%
socioeconomic = socioeconomic.set_index('PcrKey')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\gratt\repos\emsBigDataProject\stage2-dataWrangling\sex.ipynb Cell 18 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gratt/repos/emsBigDataProject/stage2-dataWrangling/sex.ipynb#X64sZmlsZQ%3D%3D?line=0'>1</a> socioeconomic = socioeconomic.set_index('PcrKey')
#
# File c:\Users\gratt\miniconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\gratt\miniconda3\lib\site-packages\pandas\core\frame.py:6001, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5998                 missing.append(col)
#    6000 if missing:
# -> 6001     raise KeyError(f"None of {missing} are in the columns")
#    6003 if inplace:
#    6004     frame = self
#
# KeyError: "None of ['PcrKey'] are in the columns"

# %%
socioeconomic = socioeconomic.join(df)

# %%
socioeconomic
# Out:
#            black  white  hispanic_latino  asian  americanIndian_alaskaNative  \
# PcrKey
# 13273412       0      1                0      0                            0
# 83733589       0      0                0      0                            1
# 88178354       0      1                0      0                            0
# 97455081       0      1                0      0                            0
# 102488422      0      1                0      0                            0
# ...          ...    ...              ...    ...                          ...
# 182540290      1      0                0      0                            0
# 182540377      1      0                0      0                            0
# 182540383      1      0                0      0                            0
# 182541657      0      1                0      0                            0
# 182544491      0      1                0      0                            0
#
#            nativeHawaiian_otherPacificIslander  ageinyear  Gender
# PcrKey
# 13273412                                     0         78     0.0
# 83733589                                     0         31     0.0
# 88178354                                     0         85     0.0
# 97455081                                     0         77     0.0
# 102488422                                    0          4     0.0
# ...                                        ...        ...     ...
# 182540290                                    0         77     0.0
# 182540377                                    0         54     1.0
# 182540383                                    0         78     0.0
# 182541657                                    0         74     1.0
# 182544491                                    0         75     1.0
#
# [32417157 rows x 8 columns]

# %%
socioeconomic = socioeconomic.rename(columns={'Gender':'sex'})

# %%
socioeconomic['sex'].value_counts(normalize=True)
# Out:
# 1.0    0.511822
# 0.0    0.488178
# Name: sex, dtype: float64

# %%
socioeconomic = socioeconomic.dropna()

# %%
socioeconomic['sex'] = socioeconomic['sex'].apply(np.int32)

# %%
socioeconomic
# Out:
#            black  white  hispanic_latino  asian  americanIndian_alaskaNative  \
# PcrKey
# 13273412       0      1                0      0                            0
# 83733589       0      0                0      0                            1
# 88178354       0      1                0      0                            0
# 97455081       0      1                0      0                            0
# 102488422      0      1                0      0                            0
# ...          ...    ...              ...    ...                          ...
# 182540290      1      0                0      0                            0
# 182540377      1      0                0      0                            0
# 182540383      1      0                0      0                            0
# 182541657      0      1                0      0                            0
# 182544491      0      1                0      0                            0
#
#            nativeHawaiian_otherPacificIslander  ageinyear  sex
# PcrKey
# 13273412                                     0         78    0
# 83733589                                     0         31    0
# 88178354                                     0         85    0
# 97455081                                     0         77    0
# 102488422                                    0          4    0
# ...                                        ...        ...  ...
# 182540290                                    0         77    0
# 182540377                                    0         54    1
# 182540383                                    0         78    0
# 182541657                                    0         74    1
# 182544491                                    0         75    1
#
# [32336363 rows x 8 columns]

# %%
socioeconomic.to_csv(r"C:\Users\gratt\Desktop\emsData\raceAgeSex.csv")

# %%
# sql stuff that i'm no longer using

# %%
# connect to sql db
from sqlalchemy import create_engine
db = create_engine(r"sqlite:///C:\Users\pat\OneDrive - Emory University\ECON496RW\emsData.db")

# %%
# create new column
add_col = 'ALTER TABLE socioeconomic ADD gender INTEGER;'
db.execute(add_col)

# %%
# we'll just export to new table for now then do the join inside sqlite
#new_table = 'CREATE TABLE genderTable (PcrKey INT PRIMARY KEY, gender INT);'
#db.execute(new_table)

# %%
df.to_sql('genderTable', con=db, index=False)
# Out:
# 41748496

# %% [markdown]
# Join Query:
#
# UPDATE socioeconomic SET gender = (SELECT Gender FROM genderTable WHERE socioeconomic.PcrKey = genderTable.PcrKey);
