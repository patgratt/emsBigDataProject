# %%
import pandas as pd

# %%
path = '/media/gratt/20882A0F8829E44E/Users/gratt/Desktop/emsData/processedCSVs/big/computedelements_chunks/computedelements_chunk1.csv'
df = pd.read_csv(path)

# %%
df
# Out:
#             PcrKey USCensusRegion    USCensusDivision   NasemsoRegion  \
# 0          1472192      Northeast         New England            East
# 1         13273412           West            Mountain            West
# 2         14548133           West            Mountain  Western Plains
# 3         17184298        Midwest  West North Central     Great Lakes
# 4         21699657        Midwest  West North Central  Western Plains
# ...            ...            ...                 ...             ...
# 4999995  126021516      Northeast     Middle Atlantic            East
# 4999996  126021517      Northeast     Middle Atlantic            East
# 4999997  126021518      Northeast     Middle Atlantic            East
# 4999998  126021519      Northeast     Middle Atlantic            East
# 4999999  126021520      Northeast     Middle Atlantic            East
#
#         Urbanicity ageinyear EMSDispatchCenterTimeSec EMSChuteTimeMin  \
# ...

# %%
df['NasemsoRegion'].value_counts()
# Out:
# South             2123012
# East              1066139
# Great Lakes        733843
# Western Plains     601130
# West               472642
# Name: NasemsoRegion, dtype: int64

# %%
df['Urbanicity'].value_counts()
# Out:
# Urban         4002130
# Rural          406936
# Suburban       339490
# Wilderness     101353
# Name: Urbanicity, dtype: int64
